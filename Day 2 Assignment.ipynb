# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df= sns.load_dataset("iris")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(data=df,x= 'petal_width',y= 'sepal_length')
# Out:
# <AxesSubplot:xlabel='petal_width', ylabel='sepal_length'>

# %%
sns.pairplot(df)

# %%
sns.barplot(data= df,x= 'petal_length', y= "species")
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='species'>

# %%
sns.barplot(data= df, x= 'petal_width', y='species')
# Out:
# <AxesSubplot:xlabel='petal_width', ylabel='species'>

# %%
sns.barplot(data= df, x= 'sepal_width', y='species')
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='species'>

# %%
sns.barplot(data= df, x= 'sepal_length', y='species')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='species'>
